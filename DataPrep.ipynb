# %%
#Missing data occurs commonly in many data analysis applications. One of the goals of pandas is to make working with missing data as painless as possible. For example, all of the descriptive statistics on pandas objects exclude missing data by default.
import pandas as pd
import numpy as np

float_data = pd.Series([1.2, -3.5, np.nan, 0])

float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])

data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],[np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])

data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how="all")
#Passing how="all" will drop only rows that are all NA:
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
#Keep in mind that these functions return new objects by default and do not modify the contents of the original object.

# %%
data[4] = np.nan
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
#To drop columns in the same way, pass axis="columns":
data[4] = np.nan
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis="columns", how="all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.standard_normal((7, 3)))

# %%
df.iloc[:4, 1] = np.nan

# %%
df.iloc[:2, 2] = np.nan
df
# Out:
#           0         1         2
# 0  0.837828       NaN       NaN
# 1  0.680403       NaN       NaN
# 2  1.518855       NaN -2.328722
# 3  0.690496       NaN  1.134099
# 4 -1.507170  0.562075  0.042582
# 5  0.544544  0.550185  2.028400
# 6  1.611830  1.191153  0.405608

# %%
 df.dropna()
# Out:
#           0         1         2
# 4 -1.507170  0.562075  0.042582
# 5  0.544544  0.550185  2.028400
# 6  1.611830  1.191153  0.405608

# %%
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2  1.518855       NaN -2.328722
# 3  0.690496       NaN  1.134099
# 4 -1.507170  0.562075  0.042582
# 5  0.544544  0.550185  2.028400
# 6  1.611830  1.191153  0.405608

# %%
 df.fillna(0)
# Out:
#           0         1         2
# 0  0.837828  0.000000  0.000000
# 1  0.680403  0.000000  0.000000
# 2  1.518855  0.000000 -2.328722
# 3  0.690496  0.000000  1.134099
# 4 -1.507170  0.562075  0.042582
# 5  0.544544  0.550185  2.028400
# 6  1.611830  1.191153  0.405608

# %%
df.fillna({1: 0.5, 2: 0})
# Out:
#           0         1         2
# 0  0.837828  0.500000  0.000000
# 1  0.680403  0.500000  0.000000
# 2  1.518855  0.500000 -2.328722
# 3  0.690496  0.500000  1.134099
# 4 -1.507170  0.562075  0.042582
# 5  0.544544  0.550185  2.028400
# 6  1.611830  1.191153  0.405608

# %%
#Removing Duplicates
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"],"k2": [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data["vsdasd"] = range(7)
data
# Out:
#     k1  k2  v1  v2  vsdasd
# 0  one   1   0   0       0
# 1  two   1   1   1       1
# 2  one   2   2   2       2
# 3  two   3   3   3       3
# 4  one   3   4   4       4
# 5  two   4   5   5       5
# 6  two   4   6   6       6

# %%
data.drop_duplicates(subset=["k1"])

#removes dublicate rows based on k1 and k1 has onyl one and twos
# Out:
#     k1  k2  v1  v2  vsdasd
# 0  one   1   0   0       0
# 1  two   1   1   1       1

# %%
data.drop_duplicates(subset=["v1"])
#as you can see nothing happend bcause v1 all diffrent
# Out:
#     k1  k2  v1  v2  vsdasd
# 0  one   1   0   0       0
# 1  two   1   1   1       1
# 2  one   2   2   2       2
# 3  two   3   3   3       3
# 4  one   3   4   4       4
# 5  two   4   5   5       5
# 6  two   4   6   6       6

# %%
data = pd.DataFrame({"food": ["bacon", "pulled pork", "bacon","pastrami", "corned beef", "bacon","pastrami", "honey ham", "nova lox"],"ounces": [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
  "bacon": "pig",
  "pulled pork": "pig",
  "pastrami": "cow",
  "corned beef": "cow",
  "honey ham": "pig",
  "nova lox": "salmon"
}

# %%
data["animal"] = data["food"].map(meat_to_animal)

data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
def get_animal(x):
    return meat_to_animal[x]

data["food"].map(get_animal)
# Out:
# 0       pig
# 1       pig
# 2       pig
# 3       cow
# 4       cow
# 5       pig
# 6       cow
# 7       pig
# 8    salmon
# Name: food, dtype: object

# %%
#renaming axis indexes
data = pd.DataFrame(np.arange(12).reshape((3, 4)),index=["Ohio", "Colorado", "New York"],columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
def transform(x):
    return x[:4].upper()
data.index.map(transform)
# Out:
# Index(['OHIO', 'COLO', 'NEW '], dtype='object')

# %%
data.index = data.index.map(transform)
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
data.rename(index=str.title, columns=str.upper)
# Out:
#       ONE  TWO  THREE  FOUR
# Ohio    0    1      2     3
# Colo    4    5      6     7
# New     8    9     10    11

# %%
data.rename(index={"OHIO": "Değişti"},columns={"three": "peekaboo"})
# Out:
#          one  two  peekaboo  four
# Değişti    0    1         2     3
# COLO       4    5         6     7
# NEW        8    9        10    11

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

bins = [18, 25, 35, 60, 100]

# %%
age_categories = pd.cut(ages, bins)
age_categories
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
group_names = ["Youth", "YoungAdult", "MiddleAged", "Senior"]

pd.cut(ages,bins,labels=group_names)
# Out:
# ['Youth', 'Youth', 'Youth', 'YoungAdult', 'Youth', ..., 'YoungAdult', 'Senior', 'MiddleAged', 'MiddleAged', 'YoungAdult']
# Length: 12
# Categories (4, object): ['Youth' < 'YoungAdult' < 'MiddleAged' < 'Senior']
